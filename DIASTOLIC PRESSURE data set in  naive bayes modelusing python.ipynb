# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("DIASTOLIC DATA SET.csv",index_col=0)
df
# Out:
#                                PLASMA GLUCOSE CONCENTRATION  \
# # 1. Number of times pregnant
# 6                                                       148
# 1                                                        85
# 8                                                       183
# 1                                                        89
# 0                                                       137
# ...                                                     ...
# 10                                                      101
# 2                                                       122
# 5                                                       121
# 1                                                       126
# 1                                                        93
#
#                                DIASTOLIC BLOOD PRESSURE  \
# # 1. Number of times pregnant
# 6                                                    72
# 1                                                    66
# 8                                                    64
# 1                                                    66
# 0                                                    40
# ...                                                 ...
# 10                                                   76
# 2                                                    70
# 5                                                    72
# 1                                                    60
# 1                                                    70
#
#                                TRICEPS SKIN FOLD THICKNESS  \
# # 1. Number of times pregnant
# 6                                                       35
# 1                                                       29
# 8                                                        0
# 1                                                       23
# 0                                                       35
# ...                                                    ...
# 10                                                      48
# 2                                                       27
# 5                                                       23
# 1                                                        0
# 1                                                       31
#
#                                2 HOUR SERUM INSULIN  BODY MASS INDEX  AGE   \
# # 1. Number of times pregnant
# 6                                                 0             33.6    50
# 1                                                 0             26.6    31
# 8                                                 0             23.3    32
# 1                                                94             28.1    21
# 0                                               168             43.1    33
# ...                                             ...              ...   ...
# 10                                              180             32.9    63
# 2                                                 0             36.8    27
# 5                                               112             26.2    30
# 1                                                 0             30.1    47
# 1                                                 0             30.4    23
#
#                                CLASS VARIABLE (0 OR 1 )
# # 1. Number of times pregnant
# 6                                                     1
# 1                                                     0
# 8                                                     1
# 1                                                     0
# 0                                                     1
# ...                                                 ...
# 10                                                    0
# 2                                                     0
# 5                                                     0
# 1                                                     1
# 1                                                     0
#
# [768 rows x 7 columns]

# %%
print(df.columns)
# Out:
# Index(['PLASMA GLUCOSE CONCENTRATION', 'DIASTOLIC BLOOD PRESSURE',
#        'TRICEPS SKIN FOLD THICKNESS', '2 HOUR SERUM INSULIN',
#        'BODY MASS INDEX', 'AGE ', 'CLASS VARIABLE (0 OR 1 )'],
#       dtype='object')

# %%
x = df.drop(columns=['DIASTOLIC BLOOD PRESSURE'])

# %%
x.head()
# Out:
#                                PLASMA GLUCOSE CONCENTRATION  \
# # 1. Number of times pregnant
# 6                                                       148
# 1                                                        85
# 8                                                       183
# 1                                                        89
# 0                                                       137
#
#                                TRICEPS SKIN FOLD THICKNESS  \
# # 1. Number of times pregnant
# 6                                                       35
# 1                                                       29
# 8                                                        0
# 1                                                       23
# 0                                                       35
#
#                                2 HOUR SERUM INSULIN  BODY MASS INDEX  AGE   \
# # 1. Number of times pregnant
# 6                                                 0             33.6    50
# 1                                                 0             26.6    31
# 8                                                 0             23.3    32
# 1                                                94             28.1    21
# 0                                               168             43.1    33
#
#                                CLASS VARIABLE (0 OR 1 )
# # 1. Number of times pregnant
# 6                                                     1
# 1                                                     0
# 8                                                     1
# 1                                                     0
# 0                                                     1

# %%
y = df['DIASTOLIC BLOOD PRESSURE'].values

# %%
y[0:5]
# Out:
# array([72, 66, 64, 66, 40], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.3)

# %%
NB = GaussianNB()

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
NB.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
NB.score(x_test,y_test)
# Out:
# 0.06493506493506493

# %%
predictions =NB.predict(x_test)

# %%
list(zip(predictions,y_test))
# Out:
# [(54, 58),
#  (54, 56),
#  (54, 66),
#  (58, 62),
#  (74, 82),
#  (82, 110),
#  (0, 58),
#  (0, 0),
#  (96, 70),
#  (54, 54),
#  (75, 86),
#  (96, 80),
#  (0, 0),
#  (54, 68),
#  (75, 68),
#  (75, 110),
#  (54, 68),
#  (70, 88),
#  (0, 70),
#  (0, 80),
#  (75, 80),
#  (78, 68),
#  (54, 74),
#  (94, 0),
#  (96, 106),
#  (0, 0),
#  (70, 72),
#  (82, 74),
#  (54, 58),
#  (64, 86),
#  (54, 70),
